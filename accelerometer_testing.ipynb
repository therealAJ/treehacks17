# %%
import serial
ser = serial.Serial('/dev/cu.usbserial-AI03Y56G', 9600)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import time
now = lambda: int(round(time.time() * 1000))

# %%
t = []
vals = []
while True:
    line = ser.readline()
    if 'accleration' in str(line):
        val = []
        for _ in range(3):
            line = ser.readline()
            end = 7 if '-' in str(line) else 6
            num = float(str(line)[2:end])
            val.append(num)
        t.append(now())
        vals.append(val)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-22bf0656b5a4> in <module>()
#       3 vals = []
#       4 while True:
# ----> 5     line = ser.readline()
#       6     if 'accleration' in str(line):
#       7         val = []
#
# /Users/ivon/anaconda/lib/python3.5/site-packages/serial/serialposix.py in read(self, size)
#     470         while len(read) < size:
#     471             try:
# --> 472                 ready, _, _ = select.select([self.fd, self.pipe_abort_read_r], [], [], timeout.time_left())
#     473                 if self.pipe_abort_read_r in ready:
#     474                     os.read(self.pipe_abort_read_r, 1000)
#
# KeyboardInterrupt:

# %%
x = [val[0] for val in vals]
plt.plot(t, x)

# %%
y = [val[1] for val in vals]
plt.plot(t, y)

# %%
z = [val[2] for val in vals]
plt.plot(t, z)
